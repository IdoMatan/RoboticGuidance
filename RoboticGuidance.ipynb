# %%
from parsing_utils import *
import os
import matplotlib.pyplot as plt
# %matplotlib inline

parser = EpisodeParser('./episodes',time_interval=0)
parser.load_episodes()
# print('Total of:',len(parser.episodes),'Valid Episodes')
# Out:
# Total of: 77/110 valid episodes

# %%
plt.rcParams['figure.figsize'] = [15, 25]
parser.plot_episode(-1)

# %%
plt.rcParams['figure.figsize'] = [15, 18]
print('Total of:',len(parser.episodes),'Valid Episodes')

parser.plot_training()
# Out:
# Total of: 76 Valid Episodes

# %%
parser.create_gif(-3,'example')
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
# Creating GIF

# %%
from IPython.display import Image
Image(filename="test.gif")
